# %%
import subprocess
import time
from threading import Thread
import os

# Configuration
NUM_MINERS = 10
BASE_PORT = 3000  # Genesis node will be at 3000
NODE_PATH = "/Users/ahmadshekha/Desktop/IT project/AI-Enhanced blockchain network for cyprocurrency exchange/P/Blockchain network"
NVM_DIR = os.path.expanduser("~/.nvm")
NVM_SH = os.path.join(NVM_DIR, "nvm.sh")

node_processes = {}

def launch_node(miner_id, port):
    """Start a blockchain node on a specific port and print its output."""
    print(f"🚀 Starting miner {miner_id} on port {port}...")

    # Build the full bash command to source nvm and run npm
    bash_command = f'''
    export NVM_DIR="{NVM_DIR}"
    [ -s "{NVM_SH}" ] && . "{NVM_SH}"
    nvm use default >/dev/null
    PORT={port} npm run dev
    '''

    process = subprocess.Popen(
        ["bash", "-c", bash_command],
        cwd=NODE_PATH,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        universal_newlines=True,
        bufsize=1
    )

    node_processes[miner_id] = process

    def stream_logs():
        for line in process.stdout:
            print(f"[Miner {miner_id} | Port {port}] {line.strip()}")

    t = Thread(target=stream_logs)
    t.daemon = True
    t.start()

# Start nodes on fixed ports (Genesis = 3000, then 3001–3011)
for i in range(NUM_MINERS):
    port = BASE_PORT + i
    launch_node(i, port)
    time.sleep(1)  # Optional delay for stability

print("\n⏳ All miners launched. Press Ctrl+C to stop them.")

# Keep script running
try:
    while True:
        time.sleep(1)
except KeyboardInterrupt:
    print("\n🛑 Shutting down all nodes...")
    for miner_id, proc in node_processes.items():
        proc.terminate()
    print("✅ All nodes terminated.")
# Out:
# 🚀 Starting miner 0 on port 3000...
# [Miner 0 | Port 3000]
# [Miner 0 | Port 3000] > cryptochain_commits@1.0.0 dev
# [Miner 0 | Port 3000] > npm run start-redis &&  nodemon index.js
# [Miner 0 | Port 3000]
# 🚀 Starting miner 1 on port 3001...
# [Miner 0 | Port 3000]
# [Miner 0 | Port 3000] > cryptochain_commits@1.0.0 start-redis
# [Miner 0 | Port 3000] > redis-server --daemonize yes
# [Miner 0 | Port 3000]
# [Miner 0 | Port 3000] [nodemon] 3.0.2
# [Miner 0 | Port 3000] [nodemon] to restart at any time, enter `rs`
# [Miner 0 | Port 3000] [nodemon] watching path(s): *.*
# [Miner 0 | Port 3000] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 0 | Port 3000] [nodemon] starting `node index.js`
# [Miner 0 | Port 3000] Connecting to NATS server...
# [Miner 0 | Port 3000] listening at localhost:3000
# [Miner 0 | Port 3000] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 0 | Port 3000] Subscribed to TEST
# [Miner 0 | Port 3000] Subscribed to BLOCKCHAIN
# [Miner 0 | Port 3000] Subscribed to TRANSACTION
# [Miner 0 | Port 3000] Subscribed to STATUS
# [Miner 0 | Port 3000] NATS PubSub initialized successfully
# [Miner 1 | Port 3001]
# [Miner 1 | Port 3001] > cryptochain_commits@1.0.0 dev
# [Miner 1 | Port 3001] > npm run start-redis &&  nodemon index.js
# [Miner 1 | Port 3001]
# 🚀 Starting miner 2 on port 3002...
# [Miner 1 | Port 3001]
# [Miner 1 | Port 3001] > cryptochain_commits@1.0.0 start-redis
# [Miner 1 | Port 3001] > redis-server --daemonize yes
# [Miner 1 | Port 3001]
# [Miner 1 | Port 3001] [nodemon] 3.0.2
# [Miner 1 | Port 3001] [nodemon] to restart at any time, enter `rs`
# [Miner 1 | Port 3001] [nodemon] watching path(s): *.*
# [Miner 1 | Port 3001] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 1 | Port 3001] [nodemon] starting `node index.js`
# [Miner 1 | Port 3001] Connecting to NATS server...
# [Miner 1 | Port 3001] listening at localhost:3001
# [Miner 1 | Port 3001] Replace chain on a sync with [
# [Miner 1 | Port 3001] {
# [Miner 1 | Port 3001] timestamp: 1,
# [Miner 1 | Port 3001] lastHash: '-----',
# [Miner 1 | Port 3001] hash: 'hash-one',
# [Miner 1 | Port 3001] data: [ [Object], [Object], [Object] ],
# [Miner 1 | Port 3001] nonce: 0,
# [Miner 1 | Port 3001] difficulty: 17,
# [Miner 1 | Port 3001] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 1 | Port 3001] }
# [Miner 1 | Port 3001] ]
# [Miner 1 | Port 3001] The incoming chain must be longer
# [Miner 1 | Port 3001] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 1 | Port 3001] Subscribed to TEST
# [Miner 1 | Port 3001] Subscribed to BLOCKCHAIN
# [Miner 1 | Port 3001] Subscribed to TRANSACTION
# [Miner 1 | Port 3001] Subscribed to STATUS
# [Miner 1 | Port 3001] NATS PubSub initialized successfully
# [Miner 1 | Port 3001] replace transaction pool map on a sync with {}
# 🚀 Starting miner 3 on port 3003...
# [Miner 2 | Port 3002]
# [Miner 2 | Port 3002] > cryptochain_commits@1.0.0 dev
# [Miner 2 | Port 3002] > npm run start-redis &&  nodemon index.js
# [Miner 2 | Port 3002]
# [Miner 2 | Port 3002]
# [Miner 2 | Port 3002] > cryptochain_commits@1.0.0 start-redis
# [Miner 2 | Port 3002] > redis-server --daemonize yes
# [Miner 2 | Port 3002]
# [Miner 2 | Port 3002] [nodemon] 3.0.2
# [Miner 2 | Port 3002] [nodemon] to restart at any time, enter `rs`
# [Miner 2 | Port 3002] [nodemon] watching path(s): *.*
# [Miner 2 | Port 3002] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 2 | Port 3002] [nodemon] starting `node index.js`
# [Miner 2 | Port 3002] Connecting to NATS server...
# [Miner 2 | Port 3002] listening at localhost:3002
# [Miner 2 | Port 3002] Replace chain on a sync with [
# [Miner 2 | Port 3002] {
# [Miner 2 | Port 3002] timestamp: 1,
# [Miner 2 | Port 3002] lastHash: '-----',
# [Miner 2 | Port 3002] hash: 'hash-one',
# [Miner 2 | Port 3002] data: [ [Object], [Object], [Object] ],
# [Miner 2 | Port 3002] nonce: 0,
# [Miner 2 | Port 3002] difficulty: 17,
# [Miner 2 | Port 3002] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 2 | Port 3002] }
# [Miner 2 | Port 3002] ]
# [Miner 2 | Port 3002] The incoming chain must be longer
# [Miner 2 | Port 3002] replace transaction pool map on a sync with {}
# [Miner 2 | Port 3002] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 2 | Port 3002] Subscribed to TEST
# [Miner 2 | Port 3002] Subscribed to BLOCKCHAIN
# [Miner 2 | Port 3002] Subscribed to TRANSACTION
# [Miner 2 | Port 3002] Subscribed to STATUS
# [Miner 2 | Port 3002] NATS PubSub initialized successfully
# 🚀 Starting miner 4 on port 3004...
# [Miner 3 | Port 3003]
# [Miner 3 | Port 3003] > cryptochain_commits@1.0.0 dev
# [Miner 3 | Port 3003] > npm run start-redis &&  nodemon index.js
# [Miner 3 | Port 3003]
# [Miner 3 | Port 3003]
# [Miner 3 | Port 3003] > cryptochain_commits@1.0.0 start-redis
# [Miner 3 | Port 3003] > redis-server --daemonize yes
# [Miner 3 | Port 3003]
# [Miner 3 | Port 3003] [nodemon] 3.0.2
# [Miner 3 | Port 3003] [nodemon] to restart at any time, enter `rs`
# [Miner 3 | Port 3003] [nodemon] watching path(s): *.*
# [Miner 3 | Port 3003] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 3 | Port 3003] [nodemon] starting `node index.js`
# [Miner 3 | Port 3003] Connecting to NATS server...
# [Miner 3 | Port 3003] listening at localhost:3003
# [Miner 3 | Port 3003] Replace chain on a sync with [
# [Miner 3 | Port 3003] {
# [Miner 3 | Port 3003] timestamp: 1,
# [Miner 3 | Port 3003] lastHash: '-----',
# [Miner 3 | Port 3003] hash: 'hash-one',
# [Miner 3 | Port 3003] data: [ [Object], [Object], [Object] ],
# [Miner 3 | Port 3003] nonce: 0,
# [Miner 3 | Port 3003] difficulty: 17,
# [Miner 3 | Port 3003] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 3 | Port 3003] }
# [Miner 3 | Port 3003] ]
# [Miner 3 | Port 3003] The incoming chain must be longer
# [Miner 3 | Port 3003] replace transaction pool map on a sync with {}
# [Miner 3 | Port 3003] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 3 | Port 3003] Subscribed to TEST
# [Miner 3 | Port 3003] Subscribed to BLOCKCHAIN
# [Miner 3 | Port 3003] Subscribed to TRANSACTION
# [Miner 3 | Port 3003] Subscribed to STATUS
# [Miner 3 | Port 3003] NATS PubSub initialized successfully
# [Miner 4 | Port 3004]
# [Miner 4 | Port 3004] > cryptochain_commits@1.0.0 dev
# [Miner 4 | Port 3004] > npm run start-redis &&  nodemon index.js
# [Miner 4 | Port 3004]
# 🚀 Starting miner 5 on port 3005...
# [Miner 4 | Port 3004]
# [Miner 4 | Port 3004] > cryptochain_commits@1.0.0 start-redis
# [Miner 4 | Port 3004] > redis-server --daemonize yes
# [Miner 4 | Port 3004]
# [Miner 4 | Port 3004] [nodemon] 3.0.2
# [Miner 4 | Port 3004] [nodemon] to restart at any time, enter `rs`
# [Miner 4 | Port 3004] [nodemon] watching path(s): *.*
# [Miner 4 | Port 3004] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 4 | Port 3004] [nodemon] starting `node index.js`
# [Miner 4 | Port 3004] Connecting to NATS server...
# [Miner 4 | Port 3004] listening at localhost:3004
# [Miner 4 | Port 3004] Replace chain on a sync with [
# [Miner 4 | Port 3004] {
# [Miner 4 | Port 3004] timestamp: 1,
# [Miner 4 | Port 3004] lastHash: '-----',
# [Miner 4 | Port 3004] hash: 'hash-one',
# [Miner 4 | Port 3004] data: [ [Object], [Object], [Object] ],
# [Miner 4 | Port 3004] nonce: 0,
# [Miner 4 | Port 3004] difficulty: 17,
# [Miner 4 | Port 3004] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 4 | Port 3004] }
# [Miner 4 | Port 3004] ]
# [Miner 4 | Port 3004] The incoming chain must be longer
# [Miner 4 | Port 3004] replace transaction pool map on a sync with {}
# [Miner 4 | Port 3004] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 4 | Port 3004] Subscribed to TEST
# [Miner 4 | Port 3004] Subscribed to BLOCKCHAIN
# [Miner 4 | Port 3004] Subscribed to TRANSACTION
# [Miner 4 | Port 3004] Subscribed to STATUS
# [Miner 4 | Port 3004] NATS PubSub initialized successfully
# 🚀 Starting miner 6 on port 3006...
# [Miner 5 | Port 3005]
# [Miner 5 | Port 3005] > cryptochain_commits@1.0.0 dev
# [Miner 5 | Port 3005] > npm run start-redis &&  nodemon index.js
# [Miner 5 | Port 3005]
# [Miner 5 | Port 3005]
# [Miner 5 | Port 3005] > cryptochain_commits@1.0.0 start-redis
# [Miner 5 | Port 3005] > redis-server --daemonize yes
# [Miner 5 | Port 3005]
# [Miner 5 | Port 3005] [nodemon] 3.0.2
# [Miner 5 | Port 3005] [nodemon] to restart at any time, enter `rs`
# [Miner 5 | Port 3005] [nodemon] watching path(s): *.*
# [Miner 5 | Port 3005] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 5 | Port 3005] [nodemon] starting `node index.js`
# [Miner 5 | Port 3005] Connecting to NATS server...
# [Miner 5 | Port 3005] listening at localhost:3005
# [Miner 5 | Port 3005] Replace chain on a sync with [
# [Miner 5 | Port 3005] {
# [Miner 5 | Port 3005] timestamp: 1,
# [Miner 5 | Port 3005] lastHash: '-----',
# [Miner 5 | Port 3005] hash: 'hash-one',
# [Miner 5 | Port 3005] data: [ [Object], [Object], [Object] ],
# [Miner 5 | Port 3005] nonce: 0,
# [Miner 5 | Port 3005] difficulty: 17,
# [Miner 5 | Port 3005] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 5 | Port 3005] }
# [Miner 5 | Port 3005] ]
# [Miner 5 | Port 3005] The incoming chain must be longer
# [Miner 5 | Port 3005] replace transaction pool map on a sync with {}
# [Miner 5 | Port 3005] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 5 | Port 3005] Subscribed to TEST
# [Miner 5 | Port 3005] Subscribed to BLOCKCHAIN
# [Miner 5 | Port 3005] Subscribed to TRANSACTION
# [Miner 5 | Port 3005] Subscribed to STATUS
# [Miner 5 | Port 3005] NATS PubSub initialized successfully
# 🚀 Starting miner 7 on port 3007...
# [Miner 6 | Port 3006]
# [Miner 6 | Port 3006] > cryptochain_commits@1.0.0 dev
# [Miner 6 | Port 3006] > npm run start-redis &&  nodemon index.js
# [Miner 6 | Port 3006]
# [Miner 6 | Port 3006]
# [Miner 6 | Port 3006] > cryptochain_commits@1.0.0 start-redis
# [Miner 6 | Port 3006] > redis-server --daemonize yes
# [Miner 6 | Port 3006]
# [Miner 6 | Port 3006] [nodemon] 3.0.2
# [Miner 6 | Port 3006] [nodemon] to restart at any time, enter `rs`
# [Miner 6 | Port 3006] [nodemon] watching path(s): *.*
# [Miner 6 | Port 3006] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 6 | Port 3006] [nodemon] starting `node index.js`
# [Miner 6 | Port 3006] Connecting to NATS server...
# [Miner 6 | Port 3006] listening at localhost:3006
# 🚀 Starting miner 8 on port 3008...
# [Miner 6 | Port 3006] Replace chain on a sync with [
# [Miner 6 | Port 3006] {
# [Miner 6 | Port 3006] timestamp: 1,
# [Miner 6 | Port 3006] lastHash: '-----',
# [Miner 6 | Port 3006] hash: 'hash-one',
# [Miner 6 | Port 3006] data: [ [Object], [Object], [Object] ],
# [Miner 6 | Port 3006] nonce: 0,
# [Miner 6 | Port 3006] difficulty: 17,
# [Miner 6 | Port 3006] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 6 | Port 3006] }
# [Miner 6 | Port 3006] ]
# [Miner 6 | Port 3006] The incoming chain must be longer
# [Miner 6 | Port 3006] replace transaction pool map on a sync with {}
# [Miner 6 | Port 3006] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 6 | Port 3006] Subscribed to TEST
# [Miner 6 | Port 3006] Subscribed to BLOCKCHAIN
# [Miner 6 | Port 3006] Subscribed to TRANSACTION
# [Miner 6 | Port 3006] Subscribed to STATUS
# [Miner 6 | Port 3006] NATS PubSub initialized successfully
# [Miner 7 | Port 3007]
# [Miner 7 | Port 3007] > cryptochain_commits@1.0.0 dev
# [Miner 7 | Port 3007] > npm run start-redis &&  nodemon index.js
# [Miner 7 | Port 3007]
# [Miner 7 | Port 3007]
# [Miner 7 | Port 3007] > cryptochain_commits@1.0.0 start-redis
# [Miner 7 | Port 3007] > redis-server --daemonize yes
# [Miner 7 | Port 3007]
# [Miner 7 | Port 3007] [nodemon] 3.0.2
# [Miner 7 | Port 3007] [nodemon] to restart at any time, enter `rs`
# [Miner 7 | Port 3007] [nodemon] watching path(s): *.*
# [Miner 7 | Port 3007] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 7 | Port 3007] [nodemon] starting `node index.js`
# [Miner 7 | Port 3007] Connecting to NATS server...
# [Miner 7 | Port 3007] listening at localhost:3007
# [Miner 7 | Port 3007] Replace chain on a sync with [
# [Miner 7 | Port 3007] {
# [Miner 7 | Port 3007] timestamp: 1,
# [Miner 7 | Port 3007] lastHash: '-----',
# [Miner 7 | Port 3007] hash: 'hash-one',
# [Miner 7 | Port 3007] data: [ [Object], [Object], [Object] ],
# [Miner 7 | Port 3007] nonce: 0,
# [Miner 7 | Port 3007] difficulty: 17,
# [Miner 7 | Port 3007] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 7 | Port 3007] }
# [Miner 7 | Port 3007] ]
# [Miner 7 | Port 3007] The incoming chain must be longer
# [Miner 7 | Port 3007] replace transaction pool map on a sync with {}
# [Miner 7 | Port 3007] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 7 | Port 3007] Subscribed to TEST
# [Miner 7 | Port 3007] Subscribed to BLOCKCHAIN
# [Miner 7 | Port 3007] Subscribed to TRANSACTION
# [Miner 7 | Port 3007] Subscribed to STATUS
# [Miner 7 | Port 3007] NATS PubSub initialized successfully
# 🚀 Starting miner 9 on port 3009...
# [Miner 8 | Port 3008]
# [Miner 8 | Port 3008] > cryptochain_commits@1.0.0 dev
# [Miner 8 | Port 3008] > npm run start-redis &&  nodemon index.js
# [Miner 8 | Port 3008]
# [Miner 8 | Port 3008]
# [Miner 8 | Port 3008] > cryptochain_commits@1.0.0 start-redis
# [Miner 8 | Port 3008] > redis-server --daemonize yes
# [Miner 8 | Port 3008]
# [Miner 8 | Port 3008] [nodemon] 3.0.2
# [Miner 8 | Port 3008] [nodemon] to restart at any time, enter `rs`
# [Miner 8 | Port 3008] [nodemon] watching path(s): *.*
# [Miner 8 | Port 3008] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 8 | Port 3008] [nodemon] starting `node index.js`
# [Miner 8 | Port 3008] Connecting to NATS server...
# [Miner 8 | Port 3008] listening at localhost:3008
# [Miner 8 | Port 3008] Replace chain on a sync with [
# [Miner 8 | Port 3008] {
# [Miner 8 | Port 3008] timestamp: 1,
# [Miner 8 | Port 3008] lastHash: '-----',
# [Miner 8 | Port 3008] hash: 'hash-one',
# [Miner 8 | Port 3008] data: [ [Object], [Object], [Object] ],
# [Miner 8 | Port 3008] nonce: 0,
# [Miner 8 | Port 3008] difficulty: 17,
# [Miner 8 | Port 3008] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 8 | Port 3008] }
# [Miner 8 | Port 3008] ]
# [Miner 8 | Port 3008] The incoming chain must be longer
# [Miner 8 | Port 3008] replace transaction pool map on a sync with {}
# [Miner 8 | Port 3008] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 8 | Port 3008] Subscribed to TEST
# [Miner 8 | Port 3008] Subscribed to BLOCKCHAIN
# [Miner 8 | Port 3008] Subscribed to TRANSACTION
# [Miner 8 | Port 3008] Subscribed to STATUS
# [Miner 8 | Port 3008] NATS PubSub initialized successfully
#
# ⏳ All miners launched. Press Ctrl+C to stop them.
# [Miner 9 | Port 3009]
# [Miner 9 | Port 3009] > cryptochain_commits@1.0.0 dev
# [Miner 9 | Port 3009] > npm run start-redis &&  nodemon index.js
# [Miner 9 | Port 3009]
# [Miner 9 | Port 3009]
# [Miner 9 | Port 3009] > cryptochain_commits@1.0.0 start-redis
# [Miner 9 | Port 3009] > redis-server --daemonize yes
# [Miner 9 | Port 3009]
# [Miner 9 | Port 3009] [nodemon] 3.0.2
# [Miner 9 | Port 3009] [nodemon] to restart at any time, enter `rs`
# [Miner 9 | Port 3009] [nodemon] watching path(s): *.*
# [Miner 9 | Port 3009] [nodemon] watching extensions: js,mjs,cjs,json
# [Miner 9 | Port 3009] [nodemon] starting `node index.js`
# [Miner 9 | Port 3009] Connecting to NATS server...
# [Miner 9 | Port 3009] listening at localhost:3009
# [Miner 9 | Port 3009] Subscribing to channels: TEST, BLOCKCHAIN, TRANSACTION, STATUS
# [Miner 9 | Port 3009] Subscribed to TEST
# [Miner 9 | Port 3009] Subscribed to BLOCKCHAIN
# [Miner 9 | Port 3009] Subscribed to TRANSACTION
# [Miner 9 | Port 3009] Subscribed to STATUS
# [Miner 9 | Port 3009] NATS PubSub initialized successfully
# [Miner 9 | Port 3009] Replace chain on a sync with [
# [Miner 9 | Port 3009] {
# [Miner 9 | Port 3009] timestamp: 1,
# [Miner 9 | Port 3009] lastHash: '-----',
# [Miner 9 | Port 3009] hash: 'hash-one',
# [Miner 9 | Port 3009] data: [ [Object], [Object], [Object] ],
# [Miner 9 | Port 3009] nonce: 0,
# [Miner 9 | Port 3009] difficulty: 17,
# [Miner 9 | Port 3009] merkleRoot: '3c94fb3210c2de9512508f21c709a1045b9126b321bd830c8dbd36c2ac46fc29'
# [Miner 9 | Port 3009] }
# [Miner 9 | Port 3009] ]
# [Miner 9 | Port 3009] The incoming chain must be longer
# [Miner 9 | Port 3009] replace transaction pool map on a sync with {}
# 🛑 Shutting down all nodes...
# ✅ All nodes terminated.
